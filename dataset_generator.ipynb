# %%
import pandas as pd

# %%
# Load your dataset
df = pd.read_csv('raw_data.csv')

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# patient_id                        0
# age_at_diagnosis                  0
# type_of_breast_surgery            0
# cancer_type                       0
# cancer_type_detailed              0
# cellularity                       0
# chemotherapy                      0
# pam50_+_claudin-low_subtype       0
# cohort                            0
# er_status_measured_by_ihc         0
# er_status                         0
# neoplasm_histologic_grade         0
# her2_status_measured_by_snp6      0
# her2_status                       0
# tumor_other_histologic_subtype    0
# hormone_therapy                   0
# inferred_menopausal_state         0
# integrative_cluster               0
# primary_tumor_laterality          0
# lymph_nodes_examined_positive     0
# mutation_count                    0
# nottingham_prognostic_index       0
# oncotree_code                     0
# overall_survival_days             0
# overall_survival                  0
# pr_status                         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1227 entries, 1 to 1902
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   patient_id                      1227 non-null   int64
#  1   age_at_diagnosis                1227 non-null   float64
#  2   type_of_breast_surgery          1227 non-null   object
#  3   cancer_type                     1227 non-null   object
#  4   cancer_type_detailed            1227 non-null   object
#  5   cellularity                     1227 non-null   object
#  6   chemotherapy                    1227 non-null   int64
#  7   pam50_+_claudin-low_subtype     1227 non-null   object
#  8   cohort                          1227 non-null   int64
#  9   er_status_measured_by_ihc       1227 non-null   object
#  10  er_status                       1227 non-null   object
#  11  neoplasm_histologic_grade       1227 non-null   float64
# ...

# %%
# Drop 'patient_id"
df.drop('patient_id', axis=1, inplace=True)

# %%
# Make 'age_at_diagnosis' an int
df['age_at_diagnosis'] = df['age_at_diagnosis'].astype(int)

# %%
# Dynamically map 'type_of_breast_surgery' values to numerical values
target = 'type_of_breast_surgery'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Drop 'cancer_type' col
df.drop('cancer_type', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1227 entries, 1 to 1902
# Data columns (total 29 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   age_at_diagnosis                          1227 non-null   int32
#  1   cancer_type_detailed                      1227 non-null   object
#  2   cellularity                               1227 non-null   object
#  3   chemotherapy                              1227 non-null   int64
#  4   pam50_+_claudin-low_subtype               1227 non-null   object
#  5   cohort                                    1227 non-null   int64
#  6   er_status_measured_by_ihc                 1227 non-null   object
#  7   er_status                                 1227 non-null   object
#  8   neoplasm_histologic_grade                 1227 non-null   float64
#  9   her2_status_measured_by_snp6              1227 non-null   object
# ...

# %%
# Dynamically map 'cancer_type_detailed' values to numerical values
target = 'cancer_type_detailed'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'cellularity' values to numerical values
target = 'cellularity'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'pam50_+_claudin-low_subtype' values to numerical values
target = 'pam50_+_claudin-low_subtype'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'er_status_measured_by_ihc' values to numerical values
target = 'er_status_measured_by_ihc'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'er_status' values to numerical values
target = 'er_status'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'her2_status_measured_by_snp6' values to numerical values
target = 'her2_status_measured_by_snp6'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'her2_status' values to numerical values
target = 'her2_status'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'tumor_other_histologic_subtype' values to numerical values
target = 'tumor_other_histologic_subtype'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'inferred_menopausal_state' values to numerical values
target = 'inferred_menopausal_state'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dropping 'integrative_cluster' beacuse of many null values
df.drop('integrative_cluster', axis=1, inplace=True)

# %%
# Dynamically map 'primary_tumor_laterality' values to numerical values
target = 'primary_tumor_laterality'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'oncotree_code' values to numerical values
target = 'oncotree_code'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Converting 'overall_survival_days' values in quarters of a year
target = 'overall_survival_days'
df[target] = df[target].astype(int)
df[target] = pd.cut(df[target], bins=range(0, 356, 88), labels=False)
df['survival_period'] = df[target] + 1

# %%
df.drop('overall_survival_days', axis=1, inplace=True)

# %%
# Dynamically map 'pr_status' values to numerical values
target = 'pr_status'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
# Dynamically map 'death_from_cancer' values to numerical values
target = 'death_from_cancer'
df = pd.get_dummies(df, columns=[target], prefix=target)
new_cols = df.filter(like=target).columns
df[new_cols] = df[new_cols].astype(int)

# %%
df.head()
# Out:
#    age_at_diagnosis  chemotherapy  cohort  neoplasm_histologic_grade  \
# 1                75             0       5                        1.0
# 3                73             0       1                        1.0
# 4                73             0       1                        1.0
# 5                34             0       1                        3.0
# 6                53             0       1                        3.0
#
#    hormone_therapy  lymph_nodes_examined_positive  mutation_count  \
# 1                0                              0             5.0
# 3                0                              0             1.0
# 4                1                              0             3.0
# 5                1                             15             2.0
# 6                0                              0             3.0
#
#    nottingham_prognostic_index  overall_survival  radio_therapy  ...  \
# 1                        2.030                 0              0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1227 entries, 1 to 1902
# Data columns (total 61 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   age_at_diagnosis                                                1227 non-null   int32
#  1   chemotherapy                                                    1227 non-null   int64
#  2   cohort                                                          1227 non-null   int64
#  3   neoplasm_histologic_grade                                       1227 non-null   float64
#  4   hormone_therapy                                                 1227 non-null   int64
#  5   lymph_nodes_examined_positive                                   1227 non-null   int64
#  6   mutation_count                                                  1227 non-null   float64
# ...

# %%
#Checking Null values
df.isnull().sum()
# Out:
# age_at_diagnosis                          0
# chemotherapy                              0
# cohort                                    0
# neoplasm_histologic_grade                 0
# hormone_therapy                           0
#                                          ..
# pr_status_Negative                        0
# pr_status_Positive                        0
# death_from_cancer_Died of Disease         0
# death_from_cancer_Died of Other Causes    0
# death_from_cancer_Living                  0
# Length: 61, dtype: int64

# %%
#Removing null values
df = df.dropna()
df.isnull().sum()
# Out:
# age_at_diagnosis                          0
# chemotherapy                              0
# cohort                                    0
# neoplasm_histologic_grade                 0
# hormone_therapy                           0
#                                          ..
# pr_status_Negative                        0
# pr_status_Positive                        0
# death_from_cancer_Died of Disease         0
# death_from_cancer_Died of Other Causes    0
# death_from_cancer_Living                  0
# Length: 61, dtype: int64

# %%
#Short description of dataframe
df.describe()
# Out:
#        age_at_diagnosis  chemotherapy       cohort  neoplasm_histologic_grade  \
# count       1226.000000   1226.000000  1226.000000                1226.000000
# mean          59.894780      0.221044     2.227569                   2.449429
# std           13.006919      0.415119     0.951694                   0.638470
# min           21.000000      0.000000     1.000000                   1.000000
# 25%           50.000000      0.000000     1.000000                   2.000000
# 50%           61.000000      0.000000     2.000000                   3.000000
# 75%           69.000000      0.000000     3.000000                   3.000000
# max           96.000000      1.000000     5.000000                   3.000000
#
#        hormone_therapy  lymph_nodes_examined_positive  mutation_count  \
# count      1226.000000                    1226.000000     1226.000000
# mean          0.608483                       1.915171        5.475530
# ...

# %%
# Column names
df.columns
# Out:
# Index(['age_at_diagnosis', 'chemotherapy', 'cohort',
#        'neoplasm_histologic_grade', 'hormone_therapy',
#        'lymph_nodes_examined_positive', 'mutation_count',
#        'nottingham_prognostic_index', 'overall_survival', 'radio_therapy',
#        'tumor_size', 'tumor_stage', 'type_of_breast_surgery_BREAST CONSERVING',
#        'type_of_breast_surgery_MASTECTOMY', 'cancer_type_detailed_Breast',
#        'cancer_type_detailed_Breast Invasive Ductal Carcinoma',
#        'cancer_type_detailed_Breast Invasive Lobular Carcinoma',
#        'cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma',
#        'cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma',
#        'cellularity_High', 'cellularity_Low', 'cellularity_Moderate',
#        'pam50_+_claudin-low_subtype_Basal', 'pam50_+_claudin-low_subtype_Her2',
#        'pam50_+_claudin-low_subtype_LumA', 'pam50_+_claudin-low_subtype_LumB',
# ...

# %%
df.to_csv('data.csv', index=False)
